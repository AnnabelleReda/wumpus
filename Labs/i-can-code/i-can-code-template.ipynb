# %% [markdown]
# # Introduction
#
# **Learning Outcomes for this workshop**
#
# By the end of this workshop, you should be able to:
# * write simple code for processing the types of data that neuroscientists work on,
# * check if that code is working as expected,
# * recall some of the operations that are useful for working with scientific data,
# * understand how computing can be use to evaluate research questions and hypotheses.
#
# ---
#
# In this workshop, you will have a gentle introduction to using computational methods to replicate findings from a *published Neuroscience research paper*:
#
# > Goffredina Spanò, Gloria Pizzamiglio, Cornelia McCormick, Ian A Clark, Sara De Felice, Thomas D Miller, Jamie O Edgin, Clive R Rosenthal, Eleanor A Maguire (2020) Dreaming with hippocampal damage, eLife 9:e56211 https://doi.org/10.7554/eLife.56211 (or copy this direct link into your browser: "elifesciences.org/articles/56211").
#
# Now follow the rest of the instructions below, writing and evaluating the code as you go along. Refer to the paper and the provided data files as indicated in the instructions below.
#
# You'll need to look at some data in this paper, so to start off, open the link above in a new browser window.

# %% [markdown]
# Your first task is to quickly identify the following things from the paper. What are the authors':
# * research question(s),
# * hypothesis,
# * methods (loosely), in terms of:
#   * participants,
#   * procedures,
#   * data collected.
#
# Take about 5 minutes to do this, focusing on the first few sections (partway through the **Results**).
#
# As you find these bits of information, enter them into this notebook by double-clicking in the box below, and typing what you found. (It does not need to be detailed.)

# %% [markdown]
# Double click below here and type in your findings (answers to the questions)
# ---
# **Research Question(s):**
# What are the differences in frequency, feature, and content in dreams of patients with hippocampal damage.
#
#
# **Hypothesis / hypotheses:**
# The frequency, feature, and content in the dreams of those with hippocampal damage are different than those without.
#
#
# **Methods:**
# Two groups, those with hippocampal damage, those without. Monitoring of sleep cycle to standardize wakings. structural mri used to asses hippocampal damage.

# %% [markdown]
# # Getting going with computing
# In the rest of this notebook, there's a mixture of text "cells" (like this), and code cells where you can type in code and execute it.
#
# Execute a code cell by clicking the arrow it its upper left-hand corner, or typing Control/Command-Enter.
#
# **Note about computing languages / environments**: In the warm-up for this workshop, I had you do the "Onramp" for **Matlab**, a language which has traditionally been used in a variety of scientific applications. *However*, it has a couple of disadvantages, which I can explain in class.
#
# In this workshop, you'll be using Google Colab, creating code in `python` with the `numpy` package, which provides data structures and coding that is very similar to MATLAB's. It's got some other advantages which I can explain as well, including a cloud computing environment.
#
# It also has some small, but pesky differences with Matlab that will be explained as they come up below.
#
# Because this computing happens "in the cloud", you'll have to "connect to a runtime" at the beginning of your session, but this should happen automatically when you execute the first cell.
#
# Changes to your notebook should be saved automatically, but it's a good practice to do `File > Save` or `Ctl/Cmd+S` from time to time to make sure they're changed. Also make sure that the file name is like `i-can-code-<your-last-name>.ipynb`.

# %% [markdown]
# # 1. Coding basics
#
# * Variables
#   * Variables store information such as numbers or text.
#   * A variable can store one value or multiple values in an array.
#   * Each stored value is referred to as an element.
#   * Variable names must start with a letter and contain only letters, numbers, and underscores. When possible, variable names should be descriptive.
#   * You can use the `print` or `display` functions to see the values of variables, e.g., `x = 42; print(x)`
#
# * Basic math operations
#   * You can perform basic math operations using numbers and/or variables.
#   * To perform basic addition, subtraction, multiplication, and division, you can use these operators:
#   `+`, `-`, `*`, `/`.
#   * Keep the order of operations ([PEMDAS](https://www.mathsisfun.com/operation-order-pemdas.html)) in mind when writing equations.
#   * More information can be found here: MathWorks Arithmetic Operations
#
# Example: Multiply the variable `x` by 4 and assign the result to the variable `y`:
#
# >  `y = x * 4`
#
# **Using the values in table 1 in Spano et al. (2020), practice working with MATLAB variables by writing the
# code below:**
#
# 1. In the code cell below, assign the LHPC volume for patient HPC1 to new variable, `vol1`. Don't forget to run the cell after putting in the code, either by clicking the circle with the arrow in the upper left of the cell or by typing CMD/Ctrl + Enter.

# %%
# Your code here. Will require 1 line of code. (This line is a comment.)
# Matlab-Colab-diff: code lines do not need to end in a semicolon.
vol1 = 2506
# In another line, you can check to see that this worked by telling it to print
# or the value (e.g., "display(vol1)"), or just return the value (e.g., "vol1").

# %% [markdown]
# **In all of your code cells, it is best practice to check/print your results. Then you and I can see if it's working.**

# %% [markdown]
# 2. Assign the average LHPC volume for control subjects to a new variable, `cntrl`.

# %%
# Your Code Here. Will require 1 line of code (plus another for verification).
cntrl = 3173.18

# %% [markdown]
# 3. Calculate the difference in LHPC volume between patient HPC1 and the average LHPC volume of control subjects by subtracting `cntrl` from `vol1` and assign it to a new variable, `diff1`.

# %%
# Your Code Here. Will require 1 line of code.

diff1 = vol1 - cntrl

# %% [markdown]
# > *Potential "gotcha": Did you notice an error in your code in a previous cell (like I did), then go back and fix it?*
#
# > Changing code in one cell *does not affect* the results in the following cells, **unless you re-evaluate those later cells**.

# %% [markdown]
# 4. Calculate the percentage LHPC volume loss of patient HPC1 relative to the average volume in controls and assign it to a new variable, `loss1`. To calculate `loss1`, divide `diff1` by `cntrl` and then multiply the result by 100.

# %%
# Your Code Here. Will require 1 line of code.

loss1 = diff1 / cntrl

# %% [markdown]
# 5. Calculate the percentage LHPC volume loss of patient HPC2 relative to the average volume in controls and assign it to a new variable, `loss2`.

# %%
# Your Code Here. Will require ~1-3 lines of code.
vol2 = 1736
diff2 = vol2 - cntrl
loss2 = diff2 / cntrl

# %% [markdown]
# 6. Calculate the percentage LHPC volume loss of patient HPC3 relative to the average volume in controls and assign it to a new variable, `loss3`.

# %%
# Your Code Here. Will require ~1-3 lines of code
vol3 = 2607
diff3 = vol3 - cntrl
loss3 = diff3 / cntrl

# %% [markdown]
# **If the results match those in Table 1 in Spano et al, (2020), you can move to the next section. If they do not, ask your instructor for help.**

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease:
# very easy

# %% [markdown]
# # 2. Arrays
#
# Within the colab environment, we will use some extra packages to create, index, and manipulate numbers within arrays.

# %% [markdown]
# ## Importing packages
#
# Next, we'll import three packages into colab which help us deal with data.
#
# * **pandas** lets us treat data as tables, and provides convenient functionality like reading a table from an excel file!
# * **numpy** (which stands for numerical python) provides almost all of the same functionality as matlab (and in a slightly cleaner way)
# * **matplotlib.pyplot** provides the same plotting functions that matlab uses,
# * **scipy.stats** includes the functions for the hypothesis testing we'll use later.
#
# We're not using all of these packages right away, but it's good practice to include your import statements near the top (unlike what we've done here) so you don't have to search through and see if you already loaded something. Execute the following cell to load these packages. (The import statements also provide short names for the package functions which will be used before the function names to distinguish them from other functions.)
#
# Run the cell below to import these packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# <a name="references"></a>
# ## Resources for help with numpy
#
# Here are some handy references for how to work with arrays in `numpy`.
#
# *   [Numpy absolute basics for beginners](https://numpy.org/doc/stable/user/absolute_beginners.html)
# *   [Numpy cheatsheet](https://www.geeksforgeeks.org/python/numpy-cheat-sheet/)
# *   [w3schools numpy tutorial](https://www.w3schools.com/python/numpy/default.asp)

# %% [markdown]
# ## Array Creation
#
# Unlike the previous results which were single numbers (also called *scalars*), with `numpy`, we can easily create matrices and vectors, i.e., structures collections of numbers. An array can have any number of dimensions. An array with either only one row or one column is referred to as a vector. You can find more information at this link: [numpy arrays and vectors](https://www2.lawrence.edu/fast/GREGGJ/Python/numpy/numpyLA.html). (*Matlab-Colab-diff: Creating arrays in numpy can be a little more cumbersome than in matlab, but it's got lots of options!*)
#
# Examples of creating basic vectors or arrays:
#
# 1x4 row vector. Use spaces or commas between elements.
#
# * `a = np.array([1, 2, 3, 4])`
#
# 4x1 column vector. **Use semicolons between rows.**
#
# * `b = np.array([[1], [8], [2], [6]])`
#
# 4x3 array:
#
# * `c = np.array([[1, 3, 5], [2, 4, 6], [7, 8, 10], [9, 12, 0]])`
#
# <h3>Array Indexing</h3>
#
# To access particular elements of an array, we use indexing. Each element within an array is positioned within a particular row and column; we can use these positions to manipulate specific elements. For more information, see this link: **MathWorks Array Indexing**
#
# Examples:
#
# Access the element in the 2nd row and 3rd column from array `c`, and assign it to the variable, x. *Matlab-Colab-diff: indices in numpy start with 0, not 1 like in matlab. And indexing is done with square brackets instead of parentheses.*
#
# * `c = np.array([[1, 3, 5], [2, 4, 6], [7, 8, 10], [9, 12, 0]])`
#
# * `x = c[1, 2]`
#
# Change the value of the element in the 1st row and 1st column of array `c` to 18.
#
# * `c[0, 0] = 18`
#
# Access the entire 3rd row, i.e the 3rd row and all columns, of array c and assign it to the variable, `x`.
#
# * `x = c[2,:]`
#
# Access the entire 2nd column, i.e the 2nd column and all rows, of array `c` and assign it to the variable, `y`.
#
# * `y = c[:,1]`
#
# **Practice working with colab arrays by writing the code below:**
#
# 7. Assign the ages of patients (HPC1-4) listed in the first column of Table 1 to a new array, `ages`, with dimensions 1 row and 4 columns (i.e., 1x4 array).

# %%
ages = [61, 72, 72, 28]

# %% [markdown]
# 8. Generate a new 2x4 array, `my_data`. In the first row, store the age of each patient (measured in years), and in the second row, record the disease chronicity for each patient (also measured in years). Ensure that each column in both rows of the array contains data pertaining to the same patient.

# %%
my_data = np.array([[61, 72, 72, 28],[6,8,11,11]])

# %% [markdown]
# 9. Extract the values in the second row of `my_data`.

# %%
x = my_data[1,:]

# %% [markdown]
# 10. Extract the values in the second column of `my_data`.

# %%
y = my_data[:,1]

# %% [markdown]
# 11. Extract the disease chronicity of the patient `HPC1` from `my_data`. To answer this, think about which row and column correspond to this value in the array `my_data`.

# %%
HPC1Chron = my_data[1,0]

# %% [markdown]
# 12. Extract the age of the patient `HPC2` from `my_data`.

# %%
HPC2Age = my_data[0,1]

# %% [markdown]
# 13. Extract the disease chronicity of the patient `HPC3` from `my_data`.

# %%
HPC3Chron = my_data[1,2]

# %% [markdown]
# **If the results match those in Table 1 in Spano et al, (2020), you can move to the next section. If they do not, ask your instructor or TA for help.**

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease:
# relatively easy
#
# * Problems:
# none

# %% [markdown]
# # 3. Working with data in arrays

# %% [markdown]
# ## Importing the data from the Spano paper
#
# This part requires a little bit of special coding in order to get the data from the excel file (provided with the original Spano et al paper) into a form that is usable in colab.
#
# The excel spreadsheet was included in the zip file where you got the template for this colab notebook. You should have unzipped this already into your Google Drive space.
#
# Next, you need to import a package that will allow colab to connect with your Google drive, and mount that location so you can see the data.
#
# Execute the following code do do this. *(Note: in the future, you can also click on the files icon to the left (which looks like a folder), and then click on the Mount drive icon in the sidebar which opens to insert this special incantation into your code.)*
#
# It will ask for permission to access your files. (Although it sounds scary) You need to give it permission to "See, edit, create, and delete all of your Google Drive files." But it may already have those permissions.
#
# **Note: If you have problems mounting the directory, see the alternate `excel_file_path` for loading the spreadsheet below.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# After you've mounted the drive, you should be able to browse through the files in the **Files** sidebar. A folder called **drive** should appear, containing all the files you have access to on Google Drive.
#
# Under that, you should see your personal google drive folder, whatever you have named it. Mine is (creatively) called `MyDrive`. Inside that folder should be your `NEU256` folder, and inside that, your `i-can-code` folder.

# %% [markdown]
# Outside of colab, open up and examine the excel file, `elife-56211-table2-data1-v1.xlsx`, so you can check what's in there, and make sure you're getting the right data. (Note that these data are partially included in the paper as Table 2, but only with individual data for the patients with hippocampus damage HPC.)
#
# After briefly referring to the excel spreadsheet (and possibly the caption of Table 2), answer the questions below about the spreadsheet data.

# %% [markdown]
# 1. Generally describe what's in the three groups of rows.
#
#
#
# 2. What's in columns I - L?
#
#
#
# 3. What's in columns M - V?
#
#
#
# 4. What's in columns B and D?
#
#
#
# 5. What's in columns F - H?

# %% [markdown]
# Next, we'll read the data from the excel file into a pandas DataFrame. A DataFrame is an object that can hold a variety of data and has (named) indices in its rows and columns.
#
# In the cell below, put in the proper path to your copy of the excel file, then run the cell.
#
# Note that the code has some extra machinery to check at first if the file is accessible. If it is, the file will be read in to a DataFrame named `df_excel`. If not, a message will be printed.

# %%
# Replace 'PATH_TO_YOUR_FILE' with the actual path to your Excel file in Google Drive
# e.g., MyDrive/NEU256/i-can-code

excel_file_path = '/content/drive/PATH_TO_YOUR_FILE/elife-56211-table2-data1-v1.xlsx'

# Alternately, if you can't mount the drive, you can uncomment this line.
excel_file_path =  'https://github.com/pmhastings/neu-code/raw/refs/heads/main/Labs/i-can-code/elife-56211-table2-data1-v1.xlsx'

try:
    df_excel = pd.read_excel(excel_file_path)
    print("Successfully loaded Excel file into pandas DataFrame.")
    display(df_excel.head())   # head method selects top n rows (default 5)
    # hover over the code to see more parameters
    # HINT: can you modify this to see the row numbers you need below?
except FileNotFoundError:
    print(f"Error: The file '{excel_file_path}' was not found. Please ensure the file exists and the path is correct.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Successfully loaded Excel file into pandas DataFrame.
# /usr/local/lib/python3.13/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                              Unnamed: 0   Unnamed: 1  Unnamed: 2   Unnamed: 3  \
# 0                                   NaN          HPC         NaN          CTL
# 1                                   NaN       M (SD)         NaN       M (SD)
# 2                    General analysesa           NaN         NaN          NaN
# 3                  Number of awakenings  6.75 (2.75)         NaN  6.90 (1.97)
# 4  Proportion of awakenings during NREM  0.73 (0.09)         NaN  0.67 (0.13)
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0         NaN        NaN        NaN        NaN       HPC1       HPC2  ...
# 1         NaN          U         ES    P-Value        NaN        NaN  ...
# ...

# %% [markdown]
# You should see (if this is successful), a bunch of data and some strange strings, like **Unnamed 0**.
#
# The strangeness is there because the authors of the paper formatted this spreadsheet so that it could be printed and included in the paper. But we're just interested in the numbers, so we'll extract just the numbers we're interested in as we go along.

# %% [markdown]
# *Note: the text and code with a green background was originally generated by Google Gemini, but then modified to make it more sensible.*
#
# The following code converts this pandas DataFrame to a NumPy array named `spano_array`, using the `.to_numpy()` method.
#
# You only have to execute this code, not write it, but examine the code to try to understand what it's doing.

# %%
if 'df_excel' in locals() and not df_excel.empty:
    # locals gives a list of everything currently in the workspace
    spano_array = df_excel.to_numpy()
    print("Successfully converted DataFrame to NumPy array.")
    print("First 5 rows of the NumPy array:")
    print(spano_array[:5])
    print("Element type of spano_array is:")
    print(spano_array.dtype)
else:
    print("DataFrame 'df_excel' is not available or is empty. Cannot convert to NumPy array.")
# Out:
# Successfully converted DataFrame to NumPy array.
# First 5 rows of the NumPy array:
# [[nan 'HPC' nan 'CTL' nan nan nan nan 'HPC1' 'HPC2' 'HPC3' 'HPC4' 'CTL1'
#   'CTL2' 'CTL3' 'CTL4' 'CTL5' 'CTL6' 'CTL7' 'CTL8' 'CTL9' 'CTL10']
#  [nan 'M (SD)' nan 'M (SD)' nan 'U' 'ES' 'P-Value' nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan]
#  ['General analysesa ' nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan]
#  ['Number of awakenings' '6.75 (2.75)' nan '6.90 (1.97)' nan 18.5 0.11
#   0.829 10 4 5 8 8 5 9 6 4 6 8 5 10 8]
#  ['Proportion of awakenings during NREM' '0.73 (0.09)' nan '0.67 (0.13)'
#   nan 14 0.47 0.383 0.8 0.75 0.6 0.75 0.75 0.6 0.89 0.67 0.75 0.67 0.63
#   0.4 0.6 0.75]]
# Element type of spano_array is:
# object

# %% [markdown]
# ## Selecting the relevant subset of data
#
# In this workshop, we'll concentrate on the first group of data which gives the individual measures for the (spoiler alert!) HPC patients and Control subjects. These data are in rows 5 - 13 and columns I - L and M - V in the original spreadsheet.
#
# *However*, things may have gotten moved around in the conversion process, so be careful you're getting the right numbers. You might want to display the `spano_array` to verify, or look at the row indices from the DataFrame.
#
# **For your convenience, I'm providing the code to do this part, but check that you understand what it's doing and that it's getting the right data.**
#
# We create a new 9x14 array called `Spano2020`, selecting the appropriate rows from `spano_array`, namely the numbers representing the measurements from all participants starting at the "Number of awakenings" row in the spreadsheet to the "Proportion of blank dreams" row. Use this selection as the first argument to `np.array`. The second argument (separated by a comma) should be `dtype=float`.
#
# > **ALERT:** Unlike matlab, numpy follows the usual convention of starting array indices at 0 instead of 1. Keep this in mind when you're accessing the data.
#
# **Verify by checking the spreadsheet that you've got the right numbers by printing your array. *Hint: It should have `[10.    4.    5.    8.    8.    5.    9.    6.    4.    6.    8.  ]` in the first row.* What should be in the last row?**
#
# **Also check the element type (dtype) of the array, as done in the code above, to check that it is `float`.**

# %%
Spano2020 = np.array(spano_array[3:12,8:22], dtype=float)
print(Spano2020)
print(Spano2020.dtype)
# Out:
# [[10.    4.    5.    8.    8.    5.    9.    6.    4.    6.    8.    5.
#   10.    8.  ]
#  [ 0.8   0.75  0.6   0.75  0.75  0.6   0.89  0.67  0.75  0.67  0.63  0.4
#    0.6   0.75]
#  [ 0.    0.25  0.4   0.25  0.25  0.4   0.11  0.33  0.25  0.33  0.38  0.6
#    0.4   0.25]
#  [ 5.8   3.5   1.6   4.38  5.63  3.2   2.89  6.    4.5   4.    2.5   4.2
#    4.4   4.88]
#  [ 0.4   0.25  0.    0.25  1.    0.8   0.22  0.83  0.5   0.33  0.75  0.4
#    1.    0.88]
#  [ 1.    0.    0.    0.5   0.75  0.5   0.5   0.6   0.5   0.    0.5   0.5
#    0.6   0.71]
#  [ 0.    1.    0.    0.5   0.25  0.5   0.5   0.4   0.5   1.    0.5   0.5
#    0.4   0.29]
#  [ 0.6   0.75  1.    0.25  0.    0.2   0.67  0.    0.5   0.17  0.13  0.4
#    0.    0.  ]
#  [ 0.    0.    0.    0.5   0.    0.    0.11  0.17  0.    0.5   0.13  0.2
#    0.    0.13]]
# float64

# %% [markdown]
# ## Array practice

# %% [markdown]
# **You can practice working with numpy arrays by writing the code below:**
#
# 14. Extract all the dream data (i.e., all rows) of patient HPC1 from the table `Spano2020` and assign it to the variable, `HPC1_dream`. Consider which column contains the data for patient HPC1.

# %%
# Your Code Here. Will require 1 line of code (plus a line for verification).
HPC1_dream = Spano2020[:, 0]
print(HPC1_dream)
# Out:
# [10.   0.8  0.   5.8  0.4  1.   0.   0.6  0. ]

# %% [markdown]
# 15. Extract the dream frequency of all 14 participants (i.e., all columns) from the table `Spano2020` and assign it to the variable `dream_fr`. Consider which row contains the dream frequency data.

# %%
# Your Code Here. Will require 1 line of code.
dream_fr = Spano2020[4]
print(dream_fr)
# Out:
# [0.4  0.25 0.   0.25 1.   0.8  0.22 0.83 0.5  0.33 0.75 0.4  1.   0.88]

# %% [markdown]
# 16. Extract the dream frequency of patient HPC1 from the table `Spano2020`. Consider which rows and columns include the data of interest.

# %%
# Your Code Here. Will require 1 line of code.
HPC1Freq = Spano2020[4,0]
print(HPC1Freq)
# Out:
# 0.4

# %% [markdown]
# 17. Extract the dream frequency of all 4 patients from the table `Spano2020`. Consider which rows and columns include the data of interest.

# %%
# Your Code Here. Will require 1 line of code.
patientFreq = Spano2020[4, 0:4]
print(patientFreq)
# Out:
# [0.4  0.25 0.   0.25]

# %% [markdown]
# **If the extracted data match those in Table 2 in Spano et al, (2020), you can move to the next section. If they do not, ask your instructor for help.**

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease:
# im forgetting what im doing when im counting
# * Problems:

# %% [markdown]
# # 4. Data analysis
#
# In this section you will conduct some basic data analysis and learn how to do the following:
#
# * compute descriptive statistics, including mean, standard deviation, and standard error,
# * performing statistical calculations using Mann-Whitney U-test and t-tests,
# * carry out within- and between-subject data analysis,
# * formulate hypotheses and interpret the results of statistical tests,
# * use colab help (To access colab help for a function, run `help(function_name)`. You can also find out about parameters for a function in your code by hovering over the function name.)

# %% [markdown]
# ## I. Within-subject analysis
#
# It's commonly thought that dreams tend to be more frequent during the REM stage of sleep compared to other stages like NREM. (Does this match what you said at the beginning of this worksheet was the Hypothesis for the Spano et al paper?) We can empirically test this idea (science!) using the data provided by Spano et al. (2020). Please do the coding below to conduct a *within-subject analysis*, specifically comparing dream proportions between REM and NREM stages for each participant (including both patients and controls).
#
# 18. Extract the data for the proportion of dreams during REM sleep for all fourteen participants from the `Spano2020` array and assign it to a new array, `data_REM`.

# %%
# Your Code Here. Will require 1 line of code.
data_REM = np.array(Spano2020[6])
print(data_REM)
# Out:
# [0.   1.   0.   0.5  0.25 0.5  0.5  0.4  0.5  1.   0.5  0.5  0.4  0.29]

# %% [markdown]
# 19. Compute the average proportion of dreams during REM sleep across all fourteen participants and assign it to the variable, `ave_REM`. To do this, use numpy's `mean` function. To compute the mean of array `X`, the general syntax is `newvar = mean(X)` where `X` is the input vector and `newvar` is assigned the output of the function (the mean of `X`).

# %%
# Your Code Here. Will require 1 line of code.
ave_REM = np.mean(data_REM)
print(ave_REM)
# Out:
# 0.4528571428571429

# %% [markdown]
# 20. Compute the standard deviation of the proportion of dreams during REM sleep across all fourteen participants and assign it to the variable, `sd_REM`. Consult the [Resources for help with numpy](#references) to look up the function to compute the standard deviation.
#
# > (Note: Due to technical stats reasons, you should use the parameter specification `ddof=1` as the second argument to the function for standard deviation. This calculates the standard deviation for a samply instead of for a population.)
#
# > *Helpful hint:* You can click on the table of contents icon at the top of the sidebar on the left to see the sections in the notebook. Then you could click on the Resources section (or click the link above). When you're done with that you can click on `I. Within-subjects analysis` to jump back to this section.

# %%
# Your Code Here. Will require 1 line of code.
sd_REM = np.std(data_REM, ddof=1)
print(sd_REM)
# Out:
# 0.29028973779335

# %% [markdown]
# 21. Compute the standard error of the proportion of dreams during REM sleep across all fourteen participants and assign it to the variable, `se_REM`. Keep in mind that while the standard error is related to standard deviation, it is not the same. To calculate the standard error, you can divide the standard deviation by the square root of the length of the vector of interest. Use the [Resources for help with numpy](#references) to look up the functions to compute the square root and the vector length.

# %%
# Your Code Here. Will require ~1 line of code.

se_REM = sd_REM / np.sqrt(len(data_REM))
print(se_REM)
# Out:
# 0.07758319583708276

# %% [markdown]
# 22. Extract the data for the proportion of dreams during NREM sleep for all fourteen participants from the table `Spano2020` and assign it to a new array, `data_NREM`

# %%
# Your Code Here. Will require 1 line of code.
data_NREM = np.array(Spano2020[5])
print(data_NREM)
# Out:
# [1.   0.   0.   0.5  0.75 0.5  0.5  0.6  0.5  0.   0.5  0.5  0.6  0.71]

# %% [markdown]
# 23. Compute the average proportion of dreams during NREM sleep across all fourteen participants and assign it to the variable, `ave_NREM`.

# %%
# Your Code Here. Will require 1 line of code.
ave_NREM = np.mean(data_NREM)
print(ave_NREM)
# Out:
# 0.47571428571428565

# %% [markdown]
# 24. Compute the standard deviation of the proportion of dreams during NREM sleep across all fourteen participants and assign it to the variable, `sd_NREM`.

# %%
# Your Code Here. Will require 1 line of code.
sd_NREM = np.std(data_NREM, ddof=1)
print(sd_NREM)
# Out:
# 0.29330252918509525

# %% [markdown]
# 25. Compute the standard error of the proportion of dreams during NREM sleep across all fourteen participants and assign it to the variable, `se_NREM`.

# %%
# Your Code Here. Will require 1 line of code.
se_NREM = sd_NREM / np.sqrt(len(data_NREM))
print(se_NREM)
# Out:
# 0.07838839820606365

# %% [markdown]
# 26. Subtract the average proportion of dreams in NREM from the average proportion of dreams in REM across all participants and assign the difference to the variable, `diff_dreams`.

# %%
# Your Code Here. Will require 1 line of code.
diff_dreams = ave_REM - ave_NREM
print(diff_dreams)
# Out:
# -0.022857142857142743

# %% [markdown]
# 27. To assess the statistical significance of the difference in the average proportion of dreams between REM and NREM across participants using a paired sample t-test in colab, you can use the `ttest` function. The general syntax for the `ttest` function is `[~,P] = ttest(X, Y)` where `X` and `Y` are the two matrices you want to compare, and P is the output p-value indicating whether the difference is statistically significant.
#
# > In this specific case, you would use `data_REM` as the array `X` and `data_NREM` as the array `Y` to calculate the p-value (output variable `P`). A `P` < 0.05 suggests a significant difference, while a `P` ≥ 0.05 indicates no significant difference between the groups. Assign your p-value to the variable, `P1`.

# %%
# Your Code Here. Will require 1 line of code.
P1 = stats.ttest(data_REM, data_NREM)
print(P1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3957/2766799675.py in <cell line: 0>()
#       1 # Your Code Here. Will require 1 line of code.
# ----> 2 P1 = stats.ttest(data_REM, data_NREM)
#       3 print(P1)
#
# AttributeError: module 'scipy.stats' has no attribute 'ttest'

# %% [markdown]
# ## II: Between-subject analysis
#
# Spano et al (2020) hypothesized that the hippocampus plays a critical role in dreaming. Therefore, they predicted that patients with hippocampal damage may experience fewer dreams than healthy controls. In the space below, write the code for a between-subject analysis, specifically comparing dream frequency between hippocampal-damaged patients and healthy controls.
#
# 28. Extract the dream frequency of the four patients into a new array, `df_HPC`.

# %%
# Your Code Here. Will require 1 line of code.
df_HPC = np.array(Spano2020[4,0:4])
print(df_HPC)
# Out:
# [0.4  0.25 0.   0.25]

# %% [markdown]
# 29. Compute the average dream frequency for all patients and assign it to the variable, `df_HPC_ave`. In addition, compute both the standard deviation and the standard error and assign these values to the variables, `df_HPC_sd` and `df_HPC_se`, respectively.

# %%
# Your Code Here. Will require 3 lines of code.

df_HPC_se = np.std(df_HPC, ddof=1) / np.sqrt(len(df_HPC))
df_HPC_sd = np.std(df_HPC, ddof=1)
df_HPC_ave = np.mean(df_HPC)
print(df_HPC_ave)
print(df_HPC_sd)
print(df_HPC_se)
# Out:
# 0.225
# 0.16583123951776998
# 0.08291561975888499

# %% [markdown]
# **If the results match Table 2 in Spano et al (2020), you can move to the next section. If not, ask the instructor for help.**

# %% [markdown]
# 30. Extract the dream frequency of the ten controls from `Spano2020` into a new array, `df_CTL`.

# %%
# Your Code Here. Will require 1 line of code.
df_CTL = np.array(Spano2020[4,4:13])
print(df_CTL)
# Out:
# [1.   0.8  0.22 0.83 0.5  0.33 0.75 0.4  1.  ]

# %% [markdown]
# 31. Compute the average dream frequency for all controls and assign it to the variable, `df_CTL_ave`. In addition, compute both the standard deviation and the standard error and assign these values to the variables, `df_CTL_sd` and `df_CTL_se`, respectively.

# %%
# Your Code Here. Will require 3 lines of code.

df_CTL_se = np.std(df_CTL, ddof=1) / np.sqrt(len(df_CTL))
df_CTL_sd = np.std(df_CTL, ddof=1)
df_CTL_ave = np.mean(df_CTL)

# %% [markdown]
# 32. Calculate the difference in average dream frequency between patients and controls by subtracting the average of `df_CTL` from the average of `df_HPC` and assign the difference to the variable, `diff_df`.

# %%
# Your Code Here. Will require 1 line of code.
diff_df = df_HPC_ave - df_CTL_ave
print(diff_df)
# Out:
# -0.4227777777777778

# %% [markdown]
# 33. To assess the statistical significance of the difference in average dream frequency between patients and controls, you can use the non-parametric Mann-Whitney U test implemented in colab with the `stats.mannwhitneyu` function. The general syntax for the function is `result = stats.mannwhitneyu(X, Y, (Continuity=True)),` where `X` and `Y` are the two matrices you want to compare. `Continuity` is an optional parameter, which should be False for our case. `result` is a structured value. You can print and `result.statistic` to see the "U" value, and `result.pvalue` to see the corresponding p-value, and **compare them with the results in Table 2.**
#
# > In this specific case, you would use `df_HPC` as the array `X` and `df_CTL` as the array `Y` to calculate the p-value (variable `P`), which indicates the significance of the difference in dream frequency between the two groups of patients and controls. A `P` < 0.05 suggests a significant difference, while a `P` > 0.05 indicates no significant difference between the groups. Assign your p-value to the variable, `P2`.

# %%
# Your code here. Will require 1 line of code.

P2 = stats.mannwhitneyu(df_HPC, df_CTL)

# %% [markdown]
# **If the p value indicates a significant difference (similar to what is reported in Table 2), you can move to the next section. Otherwise, ask your instructor or TA for help.**

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease: not terrible
#
# * Problems: so much text to get lost in

# %% [markdown]
# # 5. Plotting
#
# In the following sections, you will visualize the results of the within- and between-subject analyses using bar plots and learn the following:
#
# * Creating colab matrices for plotting
#
# * Generating Bar Graphs
#
# * Adding error bars, labels for the x and y axes, labels for the ticks on the x axis, and title
#
# * Customizing plots to imrpove data visualization
#
# * Adding comments to colab code
#
# * Saving figures as PNG files
#
# Read and run the following example code to understand how to generate bar charts in colab.
#
# For more information on matplotlib:
# * [Tutorial](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb#scrollTo=j7updWsquMfl) (We are working for now in Jupyter notebook context in Colab.)
# * [All documentation](https://matplotlib.org/stable/index.html)
# * [Examples](https://matplotlib.org/stable/gallery/index.html)

# %%
# Example code (there is no coding for you to complete here).

# Matlab colab diff:
# Matlab instructions work in a particular context.
# matplotlib (in colab) is "object-oriented".
# The subplot command below makes objects for the figure (which we won't use now),
# and axes. Then we call methods of the axes objects with appropriate parameters.

xvals = np.arange(2)     # This will be an array [0, 1]
MEAN_data = [0.2, 0.6]   # These are the mean values you want to plot.
SEM_data = [0.03, 0.07]  # These are the standard error values associated with the mean

# This makes a new plot (empty for now), and returns its figure and axes.
# We don't need the figure part of this.
fig, ax = plt.subplots()
bar_width = .6           # width of the bars

# This line generates a bar plot using the values in the MEAN_data vector
ax.bar(xvals, MEAN_data, bar_width)

# This command adds error bars to the bar plot. The errorbars will be at the
# X values 1 and 2, at the Y values of MEAN_data, using the length from
# SEM_data.
# The fmt parameter indicates a blac(k) line.
# The underscore (_) before the k says NOT to draw a line connecting the
# error bar values.
# capsize gives the width of the horizontal part at the ends of the lines.
ax.errorbar(xvals, MEAN_data, yerr=SEM_data, fmt='_k', capsize=4)

# Tell the X axis where the ticks are and what they're called.
# matlab colab diff: in matlab, can use curly brackets {} for a list.
# in colab (python), {} gives a set, which is unordered
ax.set_xticks(xvals, ['Group 1', 'Group 2'])

ax.set_xlabel('X axis label')             # This labels the x-axis as 'x'.
ax.set_ylabel('Y axis label')             # This labels the y-axis as 'y'.
ax.set_ylim([0, 0.8])          # This sets the limits of the y-axis from 0 to 0.8
ax.set_title('Example code')   # This adds a title to the plot

plt.show()                     # Display the completed plot

# %% [markdown]
# 34. Create a 1x2 array called `data2plot.` In the first column, store the average proportion of dreams during REM sleep (`ave_REM`), and in the second column, store the average proportion of dreams during NREM sleep (`ave_NREM`) for all fourteen participants.

# %%
# Your code here. Will require 1 line of code.
data2plot = np.array([ave_NREM, ave_REM])
print(data2plot)
# Out:
# [0.47571429 0.45285714]

# %% [markdown]
# 35. Create a 1x2 array called `SEM_data2plot.` In the first column, store the standard error of the proportion of dreams during REM (`se_REM`), and in the second column, store the standard error of the proportion of dreams during NREM (`se_NREM`) for all fourteen participants.

# %%
# Your code here. Will require 1 line of code.
SEM_data2plot = np.array([se_REM, se_NREM])
print(SEM_data2plot)
# Out:
# [0.0775832 0.0783884]

# %% [markdown]
# 36. Based on the example plotting code above, generate a bar chart showing the average proportion of dreams during REM and NREM sleep. Include error bars (standard error), xticks, xticks labels ('REM', and 'NREM'), label of the x-axis ('Sleep stage'), label of the y-axis ('Proportion of Dreams') and title ('Within-subject analysis, REM vs NREM'). This is figure 1.
#
# > To customize this plot adjust the y-axis limits to range from 0 to 0.6.

# %%
# Your code here. Will require ~10 lines of code.
import numpy as np
import matplotlib.pyplot as plt
xvals = np.arange(2)

fig, ax = plt.subplots()

bar_width = 0.6

ax.bar(xvals, data2plot, bar_width)

ax.errorbar(xvals, data2plot, yerr = SEM_data2plot, fmt = '_k', capsize = 4)

ax.set_xticks(xvals, ["REM", "NREM"])
ax.set_xlabel("Sleep Stage")
ax.set_ylabel("Proportion of Dreams")
ax.set_ylim([0, 0.6])
ax.set_title("Within-subject analysis, REM vs NREM")

plt.show()

# %% [markdown]
# xvalsfffeaeeee37. Based on the example plotting code above, generate a bar chart showing the average dream frequency separately for patients and controls.
#
# > Include error bars (standard error), xticks, xticks labels ('HPC', and 'CTL'), label of the x-axis ('Groups'), label of the y-axis ('Dream frequency') and title ('Between-subject analysis, dream frequency'). This is figure 2.
#
# > To customize this plot, adjust the y-axis limits to range from 0 to 1 and set the bar color to magenta. Refer to the colab documentation regarding the function `bar()` for guidance on how to do this.
#
# > Use `#` to make brief comments describing each line of your code.

# %%
# Your code here. Will require ~12 lines of code

# %% [markdown]
# **If your figure 2 matches Figure 1 panel D in Spano et al, (2020), you can move to the next section. If they do not, ask your instructor or TA for help.**

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease:
#
# * Problems:

# %% [markdown]
# # 5. Saving colab figures and code
#
# In this section you will learn the following:
#
# * Saving matplotlib figures in PNG format
# * Saving colab code

# %% [markdown]
# ## Saving figures
#
# 38. To save colab figures, use matplotlib's `savefig` method like:
#
# ```
#   figurename.savefig('filename.png', dpi=200)
# ```
#
# > Choose the PNG format. You should save the first and second figure you created with titles `Figure1.png` and `Figure2.png`, respectively.

# %% [markdown]
# ## Saving your colab notebook code
#
# When you started this workshop, you should have made a copy of this notebook, and saved it in your google drive space, in a folder for this class, with a folder called i-can-code.
#
# 39. To make sure that your notebook is saved (including code and figures!), use the `File` menu > `Save` or Ctrl/Cmd+S.

# %% [markdown]
# # 6. Questions: Answer the questions below based on the figures and statistical results you obtained.
#
# **NB: This is where the science gets real!**
#
# Create a new google doc entitled `i-can-code-<your-last-name>`. Include in it the figures listed below, and your answers to the associated questions.
#
# 1. Submit *your* Figure 1. Write a caption for Figure 1. The caption should include a descriptive title, a brief description of materials and methods, a brief description of the results, descriptive statistic(s) shown, statistical test(s) used, p-value(s), sample size (n) for all groups, explanations of figure features (e.g., symbols, lines, colors, error bars, etc.). Consult the listed websites to find out what should be included in a scientific figure caption/legend. You can also view examples from published papers on Google Scholar.
#
# * https://www.aje.com/arc/writing-effective-figure-legend/
#
# * https://www.scu.edu/provost/writingcenter/resources/subject-specific-writing/figure-caption-tips/
#
# * Other tips for figures: https://writersworkshop.illinois.edu/resources-2/writer-resources/academic-writing/style-guide-for-science-writing/
#
#
# 2. Include the Figure 2 you generated as well. Make sure it's got an informative caption.
#
# 3. Based on this data analysis, does dreaming occur more often during REM sleep compared to NREM sleep? Explain based on the average data and p-value you calculated and refer to the null hypothesis in your explanation. Use no more than 1-3 sentences.
#
# 4. Based on this data analysis, do patients with hippocampal damage experience fewer dreams? Explain based on the average data and p-value you calculated and refer to the null hypothesis in your explanation. Use no more than 1-3 sentences.

# %% [markdown]
# ## Self-report
# Were you able to complete the tasks (questions) in this section? Click in to briefly enter the **ease** with which you completed them, and what if anything caused problems.
#
# * Ease:
#
# * Problems:

# %% [markdown]
# # Submission
#
# Submit two things to  `D2L > Submissions > Labs > Lab2: i-can-code`:
#
# 1. your completed notebook (ipynb file)
# 2. your Question answers from Part 6 in gdoc, word, or pdf format.
#
# Important Note:
#
# * **Make sure you save both before submitting.**

# %% [markdown]
# # Having trouble with any of this?
#
#   * Please ask for help! I'm friendlier than I look, and I don't expect you to know all of this computer stuff at the outset.
#   * You can also ask another student. This a learning exercise, not a test! (That said, it's good to give it a try first. Colab is fairly forgiving with respect to errors.)
#   * Use TAB for listing function parameters, and completion of function names.

# %% [markdown]
# # Handy Colab Tricks
#
# 1. Show shortcuts: `CMD/CTRL M + h`.
#    * Also lets you set shortcuts!
# 2. Mount Google Drive:
#    * There's an example above in the Data Tables section, and you can set a keyboard shortcut for it.
# 3. Interrupt Execution: `CMD/CTRL M + i` if you ever get caugt in an infinite loop.
# 4. Move lines: Option/Alt + Up/Down
# 5. Delete code
#    * CMD/CTRL + Shift + K: Delete line forward
#    * CMD/CTRL + Shift + Delete: Delete all before cursor
# 6. Indenting lines: CMD/CTRL + Square brackets
# 7. Move to start/end of line: CTRL a/e
# 8. Unsure about the arguments for a function?
#    * After typing the name and left parenthesis, hit the TAB key. This can also help completing the name of a function, etc.
#    * You can also use the `help` function in a code cell, e.g., `help(np.array)`.
